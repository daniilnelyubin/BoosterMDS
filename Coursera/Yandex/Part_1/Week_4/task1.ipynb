# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
#Для задания было взато распределение хи-квадрат
#https://ru.wikipedia.org/wiki/Распределение_хи-квадрат

# %%
# d = np.random.chisquare(2,1000)
ax = sns.distplot(s,kde=False, rug=True)
plt.title("Плотность вероятности")
# Out:
# Text(0.5, 1.0, 'Плотность вероятности')

# %% [markdown]
# ### Дисперсия данного распределения: 2k = 2*2 = 4
# ### Среднее значение будет равно количеству степеней свободы т.е k, k = 2

# %%
arr1_mean = [np.mean(np.random.choice(d,5)) for i in range(1000)]
arr2_mean = [np.mean(np.random.choice(d,10)) for i in range(1000)]
arr3_mean = [np.mean(np.random.choice(d,50)) for i in range(1000)]

# %%
sns.distplot(arr1_mean, rug=True)
plt.title("Распределение выборочных средних при размере выборки 5")
print("Среднее выборки: " + str(np.mean(arr1_mean)))
print("Дисперсия выборочного среднего: " + str(np.std(arr1_mean)))
# Out:
# Среднее выборки: 2.094284843622548
# Дисперсия выборочного среднего: 0.9436182263775994

# %%
sns.distplot(arr2_mean, rug=True)
plt.title("Распределение выборочных средних при размере выборки 10")
print("Среднее выборки: " + str(np.mean(arr2_mean)))
print("Дисперсия выборочного среднего: " + str(np.std(arr2_mean)))
# Out:
# Среднее выборки: 2.033235182139683
# Дисперсия выборочного среднего: 0.6581660225710281

# %%
sns.distplot(arr3_mean, rug=True)

plt.title("Распределение выборочных средних при размере выборки 50")
print("Среднее выборки: " + str(np.mean(arr3_mean)))
print("Дисперсия выборочного среднего: " + str(np.std(arr3_mean)))
# Out:
# Среднее выборки: 2.0330733189632166
# Дисперсия выборочного среднего: 0.284035406519014

# %% [markdown]
# #### Вывод: С ростом размера выборки растет точность приближения среднего значения генеральной совокупности
